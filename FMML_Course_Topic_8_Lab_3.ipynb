# %% [markdown]
# <a href="https://colab.research.google.com/github/21JN1A4321/FMML-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 08:08:57--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  61.8MB/s    in 1.1s
#
# 2024-03-31 08:09:02 (61.8 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11361  1511.02386v2  Black box variational inference allows researc...  stat
# 8203   1612.01981v1  The intermediate map responses of a Convolutio...    cs
# 32433  1612.09057v3  We propose a new prism for studying deep learn...    cs
# 28320  1706.02025v1  Imposing constraints on the output of a Deep N...    cs
# 37972   0810.3724v2  The problem of Hybrid Linear Modeling (HLM) is...  stat
# ...             ...                                                ...   ...
# 8888   1608.08176v4  Context: Topic modeling finds human-readable s...    cs
# 7109   1710.05476v3  Excellent ranking power along with well calibr...  stat
# 10352   1301.0588v1  The generative aspect model is an extension of...    cs
# 22009   1310.8618v1  The kernel least-mean-square (KLMS) algorithm ...  stat
# 37400  1706.00327v1  Feature engineering is one of the most importa...    cs
#
#                                                    title  year  \
# 11361                    Hierarchical Variational Models  2015
# 8203    Core Sampling Framework for Pixel Classification  2016
# 32433     Deep Learning and Hierarchal Generative Models  2016
# 28320  Imposing Hard Constraints on Deep Networks: Pr...  2017
# 37972  Foundations of a Multi-way Spectral Clustering...  2008
# ...                                                  ...   ...
# 8888   What is Wrong with Topic Modeling? (and How to...  2016
# 7109                          Calibrated Boosting-Forest  2017
# 10352  Expectation-Propogation for the Generative Asp...  2012
# 22009  Convergence analysis of kernel LMS algorithm w...  2013
# 37400  One button machine for automating feature engi...  2017
#
#                                                 keywords
# 11361  [variational, inference, researchers, prototyp...
# 8203   [intermediate, responses, convolutional, infor...
# 32433  [motivated, connections, evolution, hypothesiz...
# 28320  [constraints, predictions, loosening, requirem...
# 37972  [subspaces, different, strategies, justifying,...
# ...                                                  ...
# 8888   [structures, unstructured, dirichlet, allocati...
# 7109   [excellent, calibrated, probability, estimates...
# 10352  [generative, extension, multinomial, probabili...
# 22009  [algorithm, appealing, identification, nonline...
# 37400  [engineering, important, consuming, predictive...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11361    [variational, inference, researchers, prototyp...
# 8203     [intermediate, responses, convolutional, infor...
# 32433    [motivated, connections, evolution, hypothesiz...
# 28320    [constraints, predictions, loosening, requirem...
# 37972    [subspaces, different, strategies, justifying,...
#                                ...
# 22824    [generalized, multivariate, developed, classif...
# 4593     [selection, important, preprocessing, applicat...
# 7605     [stochastic, optimization, underlying, charact...
# 35958    [functions, important, performance, optimizati...
# 12530    [characterize, asymptotic, performance, nonpar...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8922 words.
# Out of those 4572 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1659c963-d9d4-4bfa-94f5-575e63f051c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1659c963-d9d4-4bfa-94f5-575e63f051c5")) {                    Plotly.newPlot(                        "1659c963-d9d4-4bfa-94f5-575e63f051c5",                        [{"x":["computational","computation","variables","variational","distributions","parameters","approximation","structure","maintains","posterior","efficiency","efficient","hierarchical","prototype","dimensions","distribution","researchers","generalize","algorithms","continuous","algorithm","expressive","inference","information","experimentally","segmentation","usefulness","convolutional","contextual","responses","framework","understanding","classification","knowledge","processes","intermediate","pretrained","demonstrate","activation","representation","synthetic","definitions","encapsulate","hypothesize","motivated","contributions","hierarchal","performed","evolution","interaction","connections","interpolate","empirically","presented","introduce","supervised","directions","generative","probability","increasingly","efficiently","theoretically","correctly","theoretical","resulting","constraints","reasonable","proposing","perceived","technique","intractability","alternative","materialize","requirements","solutions","predictions","computationally","minimized","limitations","underlying","concentrated","performance","combination","clustering","practically","different","subspaces","parameter","foundations","justifying","curvature","strategies","sufficient","engineering","scientific","predictive","amplitude","biological","perception","precision","development","modulation","compensate","intensity","properties","producing","overlapped","frequency","prediction","phenomenon","introduces","effective","incoherent","applications","reference","successful","represented","generally","spatially","transformation","principle","therefore","conjunction","situations","recognition","capability","advantages","significant","neighborhood","surrounding","detection","observation","convolution","feedforward","similarity","generalization","invariance","appearance","including","attention","appearances","differentiable","transforms","panchromatic","misclassification","extremely","objective","extracted","multispectral","difficulties","resolution","potential","accordingly","reflectance","thresholding","procedure","absorption","comparison","integrate","classifier","graphical","increased","indicating","conditional","confusion","probabilistic","calculated","effectiveness","accelerated","regularised","nesterovs","classical","direction","iterative","approximations","interpretation","optimization","intuitive","participants","previously","developed","investigate","variability","investigations","resemblance","substantially","sensitivity","improvements","diagnostic","unexpected","independent","announced","widespread","corresponding","automatic","highlights","analysing","challenge","dermoscopic","demonstrates"],"y":[311,138,114,44,102,243,121,353,9,42,159,408,116,27,45,206,82,53,608,117,845,32,209,729,58,212,20,387,52,22,550,169,490,366,109,30,13,595,36,388,144,19,1,11,71,50,2,128,69,96,43,4,67,165,316,212,41,103,155,61,163,38,36,171,129,154,36,19,10,263,1,87,2,51,144,91,85,8,60,118,4,894,132,133,14,723,17,129,11,1,15,93,90,55,47,65,6,37,40,61,115,4,10,31,226,29,2,61,244,26,74,229,3,461,51,79,91,69,15,61,58,142,19,60,354,57,88,242,25,23,353,69,62,20,145,122,21,82,224,158,8,29,21,1,8,45,145,115,10,28,139,160,25,5,19,111,3,117,39,162,47,46,15,89,5,161,24,218,17,1,1,117,46,69,40,53,301,31,17,91,207,143,27,10,2,37,33,113,23,8,108,2,16,137,189,11,14,165,3,50],"type":"bar"},{"x":["computational","computation","variables","variat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4572,), (4572, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>Numerical</span> <span style='background-color:rgba(0, 255, 0, 0.30555555555555547);'>Integration</span> <span style=''>and</span> <span style=''>Dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discretization</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Heuristic</span> <span style=''>Search</span> <span style=''>Planning</span> <span style=''>over</span> <span style=''>Hybrid</span> <span style=''>Domains</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>look</span> <span style=''>into</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>planning</span> <span style=''>over</span> <span style=''>hybrid</span> <span style=''>domains</span> <span style=''>where</span> <span style=''>change</span> <span style=''>can</span> <span style=''>be</span> <span style=''>both</span> <span style=''>discrete</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instantaneous</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>over</span> <span style=''>time</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>it</span> <span style=''>is</span> <span style=''>required</span> <span style=''>that</span> <span style=''>each</span> <span style=''>state</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.31578947368421056);'>trajectory</span> <span style=''>induced</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7837837837837838);'>execution</span> <span style=''>of</span> <span style=''>plans</span> <span style=''>complies</span> <span style=''>with</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>We</span> <span style=''>approach</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>plans</span> <span style=''>for</span> <span style=''>such</span> <span style=''>domains</span> <span style=''>as</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.46666666666666673);'>searching</span> <span style=''>over</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>state</span> <span style=''>model</span> <span style=''>In</span> <span style=''>this</span> <span style=''>model</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>successor</span> <span style=''>states</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>solving</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615384);'>numerically</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style=''>initial</span> <span style=''>value</span> <span style=''>problem</span> <span style=''>over</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>ordinary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>(ODE)</span> <span style=''>given</span> <span style=''>by</span> <span style=''>the</span> <span style=''>current</span> <span style=''>plan</span> <span style=''>prefix</span> <span style=''>These</span> <span style='background-color:rgba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Short</span> <span style=''>term</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mortality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>for</span> <span style=''>Elderly</span> <span style=''>Patients</span> <span style=''>Using</span> <span style=''>Medicare</span> <span style=''>Claims</span> <span style=''>Data</span> <br/><br/><span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>is</span> <span style=''>central</span> <span style=''>to</span> <span style=''>both</span> <span style=''>clinical</span> <span style=''>medicine</span> <span style=''>and</span> <span style=''>public</span> <span style=''>health</span> <span style=''>While</span> <span style=''>many</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>to</span> <span style=''>predict</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mortality</span> <span style=''>they</span> <span style=''>are</span> <span style=''>rarely</span> <span style=''>applied</span> <span style=''>in</span> <span style=''>the</span> <span style=''>clinical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>One</span> <span style=''>reason</span> <span style=''>for</span> <span style=''>this</span> <span style=''>is</span> <span style=''>that</span> <span style=''>existing</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>often</span> <span style=''>seek</span> <span style=''>to</span> <span style=''>optimize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>features</span> <span style=''>that</span> <span style=''>are</span> <span style=''>not</span> <span style=''>present</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>readily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providers</span> <span style=''>and</span> <span style=''>policy</span> <span style=''>makers</span> <span style=''>limiting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>tested</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>six</span> <span style=''>month</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mortality</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>of</span> <span style=''>elderly</span> <span style=''>Medicare</span> <span style=''>beneficiaries</span> <span style=''>using</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>administrative</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.6206896551724137);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relevance</span> <span style=''>Vector</span> <span style=''>Machines</span> <br/><br/><span style=''>The</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(SVM)</span> <span style=''>of</span> <span style=''>Vapnik</span> <span style=''>(1998)</span> <span style=''>has</span> <span style=''>become</span> <span style=''>widely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>as</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>leading</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.6388888888888888);'>recognition</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>expresses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>centred</span> <span style=''>on</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>known</span> <span style=''>as</span> <span style=''>support</span> <span style=''>vectors</span> <span style=''>Despite</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>widespread</span> <span style=''>success</span> <span style=''>the</span> <span style=''>SVM</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitations</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style=''>being</span> <span style=''>that</span> <span style=''>it</span> <span style=''>makes</span> <span style=''>point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>rather</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.35135135135135137);'>generating</span> <span style='background-color:rgba(255, 0, 0, 0.4222222222222223);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3564668769716087);'>distributions</span> <span style=''>Recently</span> <span style=''>Tipping</span> <span style=''>(1999)</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulated</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relevance</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(RVM)</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>the</span> <span style=''>SVM</span> <span style=''>It</span> <span style=''>achieves</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparable</span> <span style='background-color:rgba(0, 255, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>One</span> <span style=''>Class</span> <span style=''>Support</span> <span style=''>Measure</span> <span style=''>Machines</span> <span style=''>for</span> <span style=''>Group</span> <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>one</span> <span style=''>class</span> <span style=''>support</span> <span style=''>measure</span> <span style=''>machines</span> <span style=''>(OCSMMs)</span> <span style=''>for</span> <span style=''>group</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>which</span> <span style=''>aims</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behaviors</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>The</span> <span style=''>OCSMMs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>well</span> <span style=''>known</span> <span style=''>one</span> <span style=''>class</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(OCSVMs)</span> <span style=''>to</span> <span style=''>a</span> <span style=''>space</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulating</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>quantile</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>to</span> <span style=''>the</span> <span style=''>OCSVMs</span> <span style=''>and</span> <span style=''>variable</span> <span style=''>kernel</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>(VKDEs)</span> <span style=''>over</span> <span style=''>the</span> <span style=''>input</span> <span style=''>space</span> <span style=''>on</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>defined</span> <span style=''>bridging</span> <span style=''>the</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>large</span> <span style=''>margin</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>kernel</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>various</span> <span style=''>types</span> <span style=''>of</span> <span style=''>VKDEs</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>to</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regul ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.09123563218390805)
# 	knowledge (0.1314655172413793)
# 	representation (0.13936781609195403)
# 	experimental (0.14331896551724138)
# 	segmentation (0.07614942528735633)
# 	detection (0.12679597701149425)
# 	different (0.25969827586206895)
# 	information (0.26185344827586204)
# 	recognition (0.1271551724137931)
# 	convolutional (0.13900862068965517)
#
# Some Statistics words are:
# 	algorithm (0.38591269841269843)
# 	theoretical (0.14831349206349206)
# 	estimation (0.1736111111111111)
# 	stochastic (0.14037698412698413)
# 	variables (0.14434523809523808)
# 	statistical (0.15873015873015872)
# 	distribution (0.18452380952380953)
# 	dimensional (0.19246031746031747)
# 	inference (0.19990079365079366)
# 	regression (0.1775793650793651)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="54790be1-3d0d-46cc-86ad-b40a8d72c7c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54790be1-3d0d-46cc-86ad-b40a8d72c7c3")) {                    Plotly.newPlot(                        "54790be1-3d0d-46cc-86ad-b40a8d72c7c3",                        [{"x":["computational","computation","variables","variational","distributions","parameters","approximation","structure","maintains","posterior","efficiency","efficient","hierarchical","prototype","dimensions","distribution","researchers","generalize","algorithms","continuous","algorithm","expressive","inference","information","experimentally","segmentation","usefulness","convolutional","contextual","responses","framework","understanding","classification","knowledge","processes","intermediate","pretrained","demonstrate","activation","representation","synthetic","definitions","encapsulate","hypothesize","motivated","contributions","hierarchal","performed","evolution","interaction","connections","interpolate","empirically","presented","introduce","supervised","directions","generative","probability","increasingly","efficiently","theoretically","correctly","theoretical","resulting","constraints","reasonable","proposing","perceived","technique","intractability","alternative","materialize","requirements","solutions","predictions","computationally","minimized","limitations","underlying","concentrated","performance","combination","clustering","practically","different","subspaces","parameter","foundations","justifying","curvature","strategies","sufficient","engineering","scientific","predictive","amplitude","biological","perception","precision","development","modulation","compensate","intensity","properties","producing","overlapped","frequency","prediction","phenomenon","introduces","effective","incoherent","applications","reference","successful","represented","generally","spatially","transformation","principle","therefore","conjunction","situations","recognition","capability","advantages","significant","neighborhood","surrounding","detection","observation","convolution","feedforward","similarity","generalization","invariance","appearance","including","attention","appearances","differentiable","transforms","panchromatic","misclassification","extremely","objective","extracted","multispectral","difficulties","resolution","potential","accordingly","reflectance","thresholding","procedure","absorption","comparison","integrate","classifier","graphical","increased","indicating","conditional","confusion","probabilistic","calculated","effectiveness","accelerated","regularised","nesterovs","classical","direction","iterative","approximations","interpretation","optimization","intuitive","participants","previously","developed","investigate","variability","investigations","resemblance","substantially","sensitivity","improvements","diagnostic","unexpected","independent","announced","widespread","corresponding","automatic","highlights","analysing","challenge","dermoscopic","demonstrates","perspective","discovered","disentangles","variation","disentangle","statistical","variations","postulate","learnable","specifically","interacting","controllable","postulated","extrinsic","experiment","disentangling","independently","environment","explanatory","correspond","potentially","traditionally","procedural","handcrafted","modelling","synthesis","generation","satellite","available","difficult","sequences","analyzing","complexity","reasoning","classifying","externally","supporting","construct","sufficiently","explicitly","estimation","accurately","separation","estimates","gaussians","heuristic","consistently","generated","requirement","streaming","decreasing","separated","optimally","spherical","decreases","com ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inverting
# 	simulators
# 	pediatric
# 	physiologic
# 	missforest
# 	subroutines
# 	integrator
# 	parallelisation
# 	distributionally
# 	observables
# 	prescribing
# 	amortization
# 	substitutes
# 	assimilating
# 	generalisations
# 	tightening
# 	microarrays
# 	disclosure
# 	elegantly
# 	unequally
# Some words which never appear in Statistics papers:
# 	hierarchal
# 	perceptive
# 	compensated
# 	admissible
# 	clinician
# 	affordance
# 	assistive
# 	workplace
# 	contributor
# 	investigative
# 	inspections
# 	observers
# 	neuromorphic
# 	javascript
# 	transduction
# 	intersections
# 	polyhedron
# 	participated
# 	distillation
# 	exceedingly

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085277057879798e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
